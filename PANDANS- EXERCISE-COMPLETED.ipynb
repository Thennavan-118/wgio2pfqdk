# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("housing_prices_SLR.csv")

# %%
dataset.head()
# Out:
#    AREA  PRICE
# 0  1000   5618
# 1  1030   5201
# 2  1060   4779
# 3  1090   5425
# 4  1120   5657

# %%
dataset.head(10)
# Out:
#    AREA  PRICE
# 0  1000   5618
# 1  1030   5201
# 2  1060   4779
# 3  1090   5425
# 4  1120   5657
# 5  1150   4945
# 6  1180   6475
# 7  1210   5352
# 8  1240   6290
# 9  1270   6147

# %%
dataset.head(5)
# Out:
#    AREA  PRICE
# 0  1000   5618
# 1  1030   5201
# 2  1060   4779
# 3  1090   5425
# 4  1120   5657

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AREA    50 non-null     int64
#  1   PRICE   50 non-null     int64
# dtypes: int64(2)
# memory usage: 932.0 bytes

# %%
dataset.describe()
# Out:
#               AREA       PRICE
# count    50.000000     50.0000
# mean   1735.000000  10480.8200
# std     437.321392   4043.0739
# min    1000.000000   4779.0000
# 25%    1367.500000   7554.7500
# 50%    1735.000000   9940.0000
# 75%    2102.500000  12635.2500
# max    2470.000000  22270.0000

# %%
dataset.shape
# Out:
# (50, 2)

# %%
dataset.shape[0]
# Out:
# 50

# %%
dataset.shape[1]
# Out:
# 2

# %%
dataset.columns
# Out:
# Index(['AREA', 'PRICE'], dtype='object')

# %%
dataset.null()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_244\411447244.py in ?()
# ----> 1 dataset.null()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'null'

# %%
dataset.null().head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_244\3089569465.py in ?()
# ----> 1 dataset.null().head()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'null'

# %%
dataset.isnull().head()
# Out:
#     AREA  PRICE
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False

# %%
dataset.null().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_244\3984024494.py in ?()
# ----> 1 dataset.null().sum()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'null'

# %%
dataset.isnull().sum()
# Out:
# AREA     0
# PRICE    0
# dtype: int64

# %%
dataset[['AREA']]
# Out:
#     AREA
# 0   1000
# 1   1030
# 2   1060
# 3   1090
# 4   1120
# 5   1150
# 6   1180
# 7   1210
# 8   1240
# 9   1270
# 10  1300
# 11  1330
# 12  1360
# 13  1390
# 14  1420
# 15  1450
# 16  1480
# 17  1510
# 18  1540
# 19  1570
# 20  1600
# 21  1630
# 22  1660
# 23  1690
# 24  1720
# 25  1750
# 26  1780
# 27  1810
# 28  1840
# 29  1870
# 30  1900
# 31  1930
# 32  1960
# 33  1990
# 34  2020
# 35  2050
# 36  2080
# 37  2110
# 38  2140
# 39  2170
# 40  2200
# 41  2230
# 42  2260
# 43  2290
# 44  2320
# 45  2350
# 46  2380
# 47  2410
# 48  2440
# 49  2470

# %%
dataset[['AREA','PRICE']]
# Out:
#     AREA  PRICE
# 0   1000   5618
# 1   1030   5201
# 2   1060   4779
# 3   1090   5425
# 4   1120   5657
# 5   1150   4945
# 6   1180   6475
# 7   1210   5352
# 8   1240   6290
# 9   1270   6147
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968
# 17  1510   7614
# 18  1540   9762
# 19  1570  10067
# 20  1600   8074
# 21  1630  10201
# 22  1660  10051
# 23  1690   9775
# 24  1720  10229
# 25  1750   8314
# 26  1780   9288
# 27  1810  10503
# 28  1840   9763
# 29  1870  11527
# 30  1900   9912
# 31  1930  10204
# 32  1960   9085
# 33  1990  10240
# 34  2020  15220
# 35  2050  12278
# 36  2080  22270
# 37  2110  12574
# 38  2140  12618
# 39  2170  15457
# 40  2200  12793
# 41  2230  12641
# 42  2260  17207
# 43  2290  16969
# 44  2320  16293
# 45  2350  16845
# 46  2380  17604
# 47  2410  17310
# 48  2440  14036
# 49  2470  13699

# %%
dataset[dataset.index==10]
# Out:
#     AREA  PRICE
# 10  1300   7718

# %%
dataset[dataset.index>=10]
# Out:
#     AREA  PRICE
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968
# 17  1510   7614
# 18  1540   9762
# 19  1570  10067
# 20  1600   8074
# 21  1630  10201
# 22  1660  10051
# 23  1690   9775
# 24  1720  10229
# 25  1750   8314
# 26  1780   9288
# 27  1810  10503
# 28  1840   9763
# 29  1870  11527
# 30  1900   9912
# 31  1930  10204
# 32  1960   9085
# 33  1990  10240
# 34  2020  15220
# 35  2050  12278
# 36  2080  22270
# 37  2110  12574
# 38  2140  12618
# 39  2170  15457
# 40  2200  12793
# 41  2230  12641
# 42  2260  17207
# 43  2290  16969
# 44  2320  16293
# 45  2350  16845
# 46  2380  17604
# 47  2410  17310
# 48  2440  14036
# 49  2470  13699

# %%
dataset[dataset.index.isin(range(0,20))]
# Out:
#     AREA  PRICE
# 0   1000   5618
# 1   1030   5201
# 2   1060   4779
# 3   1090   5425
# 4   1120   5657
# 5   1150   4945
# 6   1180   6475
# 7   1210   5352
# 8   1240   6290
# 9   1270   6147
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968
# 17  1510   7614
# 18  1540   9762
# 19  1570  10067

# %%
dataset.loc[1]
# Out:
# AREA     1030
# PRICE    5201
# Name: 1, dtype: int64

# %%
dataset.iloc[:,]
# Out:
#     AREA  PRICE
# 0   1000   5618
# 1   1030   5201
# 2   1060   4779
# 3   1090   5425
# 4   1120   5657
# 5   1150   4945
# 6   1180   6475
# 7   1210   5352
# 8   1240   6290
# 9   1270   6147
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968
# 17  1510   7614
# 18  1540   9762
# 19  1570  10067
# 20  1600   8074
# 21  1630  10201
# 22  1660  10051
# 23  1690   9775
# 24  1720  10229
# 25  1750   8314
# 26  1780   9288
# 27  1810  10503
# 28  1840   9763
# 29  1870  11527
# 30  1900   9912
# 31  1930  10204
# 32  1960   9085
# 33  1990  10240
# 34  2020  15220
# 35  2050  12278
# 36  2080  22270
# 37  2110  12574
# 38  2140  12618
# 39  2170  15457
# 40  2200  12793
# 41  2230  12641
# 42  2260  17207
# 43  2290  16969
# 44  2320  16293
# 45  2350  16845
# 46  2380  17604
# 47  2410  17310
# 48  2440  14036
# 49  2470  13699

# %%
dataset.iloc[0:4,1:]
# Out:
#    PRICE
# 0   5618
# 1   5201
# 2   4779
# 3   5425

# %%
dataset.iloc[0:5,0:1]
# Out:
#    AREA
# 0  1000
# 1  1030
# 2  1060
# 3  1090
# 4  1120

# %%
dataset.iloc[:,:]
# Out:
#     AREA  PRICE
# 0   1000   5618
# 1   1030   5201
# 2   1060   4779
# 3   1090   5425
# 4   1120   5657
# 5   1150   4945
# 6   1180   6475
# 7   1210   5352
# 8   1240   6290
# 9   1270   6147
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968
# 17  1510   7614
# 18  1540   9762
# 19  1570  10067
# 20  1600   8074
# 21  1630  10201
# 22  1660  10051
# 23  1690   9775
# 24  1720  10229
# 25  1750   8314
# 26  1780   9288
# 27  1810  10503
# 28  1840   9763
# 29  1870  11527
# 30  1900   9912
# 31  1930  10204
# 32  1960   9085
# 33  1990  10240
# 34  2020  15220
# 35  2050  12278
# 36  2080  22270
# 37  2110  12574
# 38  2140  12618
# 39  2170  15457
# 40  2200  12793
# 41  2230  12641
# 42  2260  17207
# 43  2290  16969
# 44  2320  16293
# 45  2350  16845
# 46  2380  17604
# 47  2410  17310
# 48  2440  14036
# 49  2470  13699

# %%
dataset.loc[0:2,['AREA','PRICE']]
# Out:
#    AREA  PRICE
# 0  1000   5618
# 1  1030   5201
# 2  1060   4779

# %%
dataset.iloc[0:2,:]
# Out:
#    AREA  PRICE
# 0  1000   5618
# 1  1030   5201

# %%
dataset.loc[dataset['AREA']==1030,['AREA']]=2879

# %%
dataset
# Out:
#     AREA  PRICE
# 0   1000   5618
# 1   2879   5201
# 2   1060   4779
# 3   1090   5425
# 4   1120   5657
# 5   1150   4945
# 6   1180   6475
# 7   1210   5352
# 8   1240   6290
# 9   1270   6147
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968
# 17  1510   7614
# 18  1540   9762
# 19  1570  10067
# 20  1600   8074
# 21  1630  10201
# 22  1660  10051
# 23  1690   9775
# 24  1720  10229
# 25  1750   8314
# 26  1780   9288
# 27  1810  10503
# 28  1840   9763
# 29  1870  11527
# 30  1900   9912
# 31  1930  10204
# 32  1960   9085
# 33  1990  10240
# 34  2020  15220
# 35  2050  12278
# 36  2080  22270
# 37  2110  12574
# 38  2140  12618
# 39  2170  15457
# 40  2200  12793
# 41  2230  12641
# 42  2260  17207
# 43  2290  16969
# 44  2320  16293
# 45  2350  16845
# 46  2380  17604
# 47  2410  17310
# 48  2440  14036
# 49  2470  13699

# %%
dataset[dataset.AREA==2879]
# Out:
#    AREA  PRICE
# 1  2879   5201

# %%
dataset.loc[dataset['AREA']>2020,'PRICE']
# Out:
# 1      5201
# 35    12278
# 36    22270
# 37    12574
# 38    12618
# 39    15457
# 40    12793
# 41    12641
# 42    17207
# 43    16969
# 44    16293
# 45    16845
# 46    17604
# 47    17310
# 48    14036
# 49    13699
# Name: PRICE, dtype: int64

# %%
dataset.columns=['OURAREA','OURPRICE']

# %%
dataset
# Out:
#     OURAREA  OURPRICE
# 0      1000      5618
# 1      2879      5201
# 2      1060      4779
# 3      1090      5425
# 4      1120      5657
# 5      1150      4945
# 6      1180      6475
# 7      1210      5352
# 8      1240      6290
# 9      1270      6147
# 10     1300      7718
# 11     1330      7035
# 12     1360      8712
# 13     1390      9457
# 14     1420      7304
# 15     1450      7535
# 16     1480      9968
# 17     1510      7614
# 18     1540      9762
# 19     1570     10067
# 20     1600      8074
# 21     1630     10201
# 22     1660     10051
# 23     1690      9775
# 24     1720     10229
# 25     1750      8314
# 26     1780      9288
# 27     1810     10503
# 28     1840      9763
# 29     1870     11527
# 30     1900      9912
# 31     1930     10204
# 32     1960      9085
# 33     1990     10240
# 34     2020     15220
# 35     2050     12278
# 36     2080     22270
# 37     2110     12574
# 38     2140     12618
# 39     2170     15457
# ...

# %%
dataset.mean()
# Out:
# OURAREA      1771.98
# OURPRICE    10480.82
# dtype: float64

# %%
dataset.mode()
# Out:
#     OURAREA  OURPRICE
# 0      1000      4779
# 1      1060      4945
# 2      1090      5201
# 3      1120      5352
# 4      1150      5425
# 5      1180      5618
# 6      1210      5657
# 7      1240      6147
# 8      1270      6290
# 9      1300      6475
# 10     1330      7035
# 11     1360      7304
# 12     1390      7535
# 13     1420      7614
# 14     1450      7718
# 15     1480      8074
# 16     1510      8314
# 17     1540      8712
# 18     1570      9085
# 19     1600      9288
# 20     1630      9457
# 21     1660      9762
# 22     1690      9763
# 23     1720      9775
# 24     1750      9912
# 25     1780      9968
# 26     1810     10051
# 27     1840     10067
# 28     1870     10201
# 29     1900     10204
# 30     1930     10229
# 31     1960     10240
# 32     1990     10503
# 33     2020     11527
# 34     2050     12278
# 35     2080     12574
# 36     2110     12618
# 37     2140     12641
# 38     2170     12793
# 39     2200     13699
# ...

# %%
dataset['updatedata']=dataset['OURAREA']/dataset['OURPRICE']

# %%
dataset
# Out:
#     OURAREA  OURPRICE  updatedata
# 0      1000      5618    0.177999
# 1      2879      5201    0.553547
# 2      1060      4779    0.221804
# 3      1090      5425    0.200922
# 4      1120      5657    0.197985
# 5      1150      4945    0.232558
# 6      1180      6475    0.182239
# 7      1210      5352    0.226084
# 8      1240      6290    0.197138
# 9      1270      6147    0.206605
# 10     1300      7718    0.168437
# 11     1330      7035    0.189055
# 12     1360      8712    0.156107
# 13     1390      9457    0.146981
# 14     1420      7304    0.194414
# 15     1450      7535    0.192435
# 16     1480      9968    0.148475
# 17     1510      7614    0.198319
# 18     1540      9762    0.157755
# 19     1570     10067    0.155955
# 20     1600      8074    0.198167
# 21     1630     10201    0.159788
# 22     1660     10051    0.165158
# 23     1690      9775    0.172890
# 24     1720     10229    0.168149
# 25     1750      8314    0.210488
# ...

# %%
dataset['updatedata'].value_counts()
# Out:
# updatedata
# 0.177999    1
# 0.167807    1
# 0.172332    1
# 0.188467    1
# 0.162228    1
# 0.191687    1
# 0.189142    1
# 0.215740    1
# 0.194336    1
# 0.132720    1
# 0.166965    1
# 0.093399    1
# 0.169599    1
# 0.553547    1
# 0.140389    1
# 0.171969    1
# 0.176410    1
# 0.131342    1
# 0.134952    1
# 0.142392    1
# 0.139507    1
# 0.135197    1
# 0.139226    1
# 0.173839    1
# 0.191645    1
# 0.210488    1
# 0.168149    1
# 0.172890    1
# 0.221804    1
# 0.200922    1
# 0.197985    1
# 0.232558    1
# 0.182239    1
# 0.226084    1
# 0.197138    1
# 0.206605    1
# 0.168437    1
# 0.189055    1
# 0.156107    1
# 0.146981    1
# 0.194414    1
# 0.192435    1
# 0.148475    1
# 0.198319    1
# 0.157755    1
# 0.155955    1
# 0.198167    1
# 0.159788    1
# 0.165158    1
# 0.180305    1
# Name: count, dtype: int64

# %%
dataset.groupby('OURPRICE').mean()
# Out:
#           OURAREA  updatedata
# OURPRICE
# 4779       1060.0    0.221804
# 4945       1150.0    0.232558
# 5201       2879.0    0.553547
# 5352       1210.0    0.226084
# 5425       1090.0    0.200922
# 5618       1000.0    0.177999
# 5657       1120.0    0.197985
# 6147       1270.0    0.206605
# 6290       1240.0    0.197138
# 6475       1180.0    0.182239
# 7035       1330.0    0.189055
# 7304       1420.0    0.194414
# 7535       1450.0    0.192435
# 7614       1510.0    0.198319
# 7718       1300.0    0.168437
# 8074       1600.0    0.198167
# 8314       1750.0    0.210488
# 8712       1360.0    0.156107
# 9085       1960.0    0.215740
# 9288       1780.0    0.191645
# 9457       1390.0    0.146981
# 9762       1540.0    0.157755
# 9763       1840.0    0.188467
# 9775       1690.0    0.172890
# 9912       1900.0    0.191687
# 9968       1480.0    0.148475
# 10051      1660.0    0.165158
# 10067      1570.0    0.155955
# 10201      1630.0    0.159788
# ...

# %%
dataset.groupby('OURPRICE').mean().sort_values(by='OURPRICE',ascending=False)
# Out:
#           OURAREA  updatedata
# OURPRICE
# 22270      2080.0    0.093399
# 17604      2380.0    0.135197
# 17310      2410.0    0.139226
# 17207      2260.0    0.131342
# 16969      2290.0    0.134952
# 16845      2350.0    0.139507
# 16293      2320.0    0.142392
# 15457      2170.0    0.140389
# 15220      2020.0    0.132720
# 14036      2440.0    0.173839
# 13699      2470.0    0.180305
# 12793      2200.0    0.171969
# 12641      2230.0    0.176410
# 12618      2140.0    0.169599
# 12574      2110.0    0.167807
# 12278      2050.0    0.166965
# 11527      1870.0    0.162228
# 10503      1810.0    0.172332
# 10240      1990.0    0.194336
# 10229      1720.0    0.168149
# 10204      1930.0    0.189142
# 10201      1630.0    0.159788
# 10067      1570.0    0.155955
# 10051      1660.0    0.165158
# 9968       1480.0    0.148475
# 9912       1900.0    0.191687
# 9775       1690.0    0.172890
# 9763       1840.0    0.188467
# 9762       1540.0    0.157755
# ...

# %%
import pandas as pd
lst=["apple","orange","papaya"]
df=pd.DataFrame(lst)
df
# Out:
#         0
# 0   apple
# 1  orange
# 2  papaya

# %%
import pandas as pd
data={'Name':['shank','ram'],'Dept':['cse','eee']}
df=pd.DataFrame(data)

# %%
print(df['Name'])
print(df['Dept'])
# Out:
# 0    shank
# 1      ram
# Name: Name, dtype: object
# 0    cse
# 1    eee
# Name: Dept, dtype: object

# %%
import pandas as pd
df1=df=pd.DataFrame({"a":[1,2,3,4],"b":[3,2,7,8]})
df2=df=pd.DataFrame({"a":[1,2,3],"b":[3,2,7]})
print("dataframe")
print(df1,"\n")
print(df2,"\n")
result=pd.concat([df1,df2])
print(result)
# Out:
# dataframe
#    a  b
# 0  1  3
# 1  2  2
# 2  3  7
# 3  4  8
#
#    a  b
# 0  1  3
# 1  2  2
# 2  3  7
#
#    a  b
# 0  1  3
# 1  2  2
# 2  3  7
# 3  4  8
# 0  1  3
# 1  2  2
# 2  3  7

# %% [raw]
# from datetime import date
# d=date(2024,4,4)
# print(d)
# print(type(d))

# %%
from datetime import time
t=time(11,50,11,50)
print(t)
print(type(t))
# Out:
# 11:50:11.000050
# <class 'datetime.time'>

# %%
import pandas as pd
dataset=pd.read_csv("housing_prices_SLR.csv")
print(dataset.index)
dataset.drop([2],inplace=True)
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
import pandas as pd
dataset=pd.read_csv("housing_prices_SLR.csv")
print(dataset.index)
dataset.drop([2],inplace=True) 
print(dataset)
# Out:
# RangeIndex(start=0, stop=50, step=1)
#     AREA  PRICE
# 0   1000   5618
# 1   1030   5201
# 3   1090   5425
# 4   1120   5657
# 5   1150   4945
# 6   1180   6475
# 7   1210   5352
# 8   1240   6290
# 9   1270   6147
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968
# 17  1510   7614
# 18  1540   9762
# 19  1570  10067
# 20  1600   8074
# 21  1630  10201
# 22  1660  10051
# 23  1690   9775
# 24  1720  10229
# 25  1750   8314
# 26  1780   9288
# 27  1810  10503
# 28  1840   9763
# 29  1870  11527
# 30  1900   9912
# 31  1930  10204
# 32  1960   9085
# 33  1990  10240
# 34  2020  15220
# 35  2050  12278
# 36  2080  22270
# 37  2110  12574
# 38  2140  12618
# 39  2170  15457
# 40  2200  12793
# 41  2230  12641
# 42  2260  17207
# 43  2290  16969
# 44  2320  16293
# 45  2350  16845
# 46  2380  17604
# 47  2410  17310
# 48  2440  14036
# 49  2470  13699

# %%
import pandas as pd

dataset = pd.read_csv("housing_prices_SLR.csv")

# Check the current indices
print(dataset.index)

# If the indices are numeric, you can drop rows using their index labels
dataset.drop([2], inplace=True)

# Print the updated dataset
print(dataset)
# Out:
# RangeIndex(start=0, stop=50, step=1)
#     AREA  PRICE
# 0   1000   5618
# 1   1030   5201
# 3   1090   5425
# 4   1120   5657
# 5   1150   4945
# 6   1180   6475
# 7   1210   5352
# 8   1240   6290
# 9   1270   6147
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968
# 17  1510   7614
# 18  1540   9762
# 19  1570  10067
# 20  1600   8074
# 21  1630  10201
# 22  1660  10051
# 23  1690   9775
# 24  1720  10229
# 25  1750   8314
# 26  1780   9288
# 27  1810  10503
# 28  1840   9763
# 29  1870  11527
# 30  1900   9912
# 31  1930  10204
# 32  1960   9085
# 33  1990  10240
# 34  2020  15220
# 35  2050  12278
# 36  2080  22270
# 37  2110  12574
# 38  2140  12618
# 39  2170  15457
# 40  2200  12793
# 41  2230  12641
# 42  2260  17207
# 43  2290  16969
# 44  2320  16293
# 45  2350  16845
# 46  2380  17604
# 47  2410  17310
# 48  2440  14036
# 49  2470  13699

# %%
dataset.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'df' is your Pandas DataFrame
value_counts = dataset['AREA'].value_counts()
value_counts.plot.bar()
plt.show()

# %%
dataset.boxplot(column=['PRICE'],by='PRICE')
# Out:
# <Axes: title={'center': 'PRICE'}, xlabel='PRICE'>

# %%
dataset.boxplot(figsize=(20,10),column=['PRICE'],by='PRICE')
# Out:
# <Axes: title={'center': 'PRICE'}, xlabel='PRICE'>

# %%
plt.plot(dataset['AREA'],dataset['AREA'],label='AREA')
plt.plot(dataset['PRICE'],dataset['PRICE'],label='PRICE')
plt.legend()
plt.show()
